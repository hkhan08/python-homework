# %%
import pandas as pd
budget = pd.read_csv("C:/Users/khanh/OneDrive/Desktop/Fintech and Blockchain Bootcamp/test folder/PyBank/budget_data.csv")
budget
# Out:
#         Date  Profit/Losses
# 0   Jan-2010         867884
# 1   Feb-2010         984655
# 2   Mar-2010         322013
# 3   Apr-2010         -69417
# 4   May-2010         310503
# ..       ...            ...
# 81  Oct-2016         102685
# 82  Nov-2016         795914
# 83  Dec-2016          60988
# 84  Jan-2017         138230
# 85  Feb-2017         671099
#
# [86 rows x 2 columns]

# %%
budget['Change'] = budget['Profit/Losses'].diff()
budget
# Out:
#         Date  Profit/Losses    Change
# 0   Jan-2010         867884       NaN
# 1   Feb-2010         984655  116771.0
# 2   Mar-2010         322013 -662642.0
# 3   Apr-2010         -69417 -391430.0
# 4   May-2010         310503  379920.0
# ..       ...            ...       ...
# 81  Oct-2016         102685 -665765.0
# 82  Nov-2016         795914  693229.0
# 83  Dec-2016          60988 -734926.0
# 84  Jan-2017         138230   77242.0
# 85  Feb-2017         671099  532869.0
#
# [86 rows x 3 columns]

# %%
import numpy
print("Financial Analysis")
print("Total Months:", budget.shape[0])
print("Total:", sum(budget['Profit/Losses']))
print("Average Change:", numpy.mean(budget['Change']))
print("Greatest Increase in Profits:", budget['Date'].iloc[budget['Change'].idxmax()], budget['Change'].max())
print("Greatest Decrease in Profits:", budget['Date'].iloc[budget['Change'].idxmin()], budget['Change'].min())
# Out:
# Financial Analysis
# Total Months: 86
# Total: 38382578
# Average Change: -2315.1176470588234
# Greatest Increase in Profits: Feb-2012 1926159.0
# Greatest Decrease in Profits: Sep-2013 -2196167.0

# %%
import csv
with open(csvpath, "r") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
    csv_header = next(csvreader)
    print (csv_header)
    for row in csvreader:
        # print(row)
        # date = row[0]
        # P_L = int(row[1])
        sales.append(row)
# Out:
# ['Date', 'Profit/Losses']

# %%
sales
# Out:
# [['Jan-2010', '867884'],
#  ['Feb-2010', '984655'],
#  ['Mar-2010', '322013'],
#  ['Apr-2010', '-69417'],
#  ['May-2010', '310503'],
#  ['Jun-2010', '522857'],
#  ['Jul-2010', '1033096'],
#  ['Aug-2010', '604885'],
#  ['Sep-2010', '-216386'],
#  ['Oct-2010', '477532'],
#  ['Nov-2010', '893810'],
#  ['Dec-2010', '-80353'],
#  ['Jan-2011', '779806'],
#  ['Feb-2011', '-335203'],
#  ['Mar-2011', '697845'],
#  ['Apr-2011', '793163'],
#  ['May-2011', '485070'],
#  ['Jun-2011', '584122'],
#  ['Jul-2011', '62729'],
#  ['Aug-2011', '668179'],
#  ['Sep-2011', '899906'],
#  ['Oct-2011', '834719'],
#  ['Nov-2011', '132003'],
#  ['Dec-2011', '309978'],
#  ['Jan-2012', '-755566'],
#  ['Feb-2012', '1170593'],
#  ['Mar-2012', '252788'],
#  ['Apr-2012', '1151518'],
#  ['May-2012', '817256'],
#  ['Jun-2012', '570757'],
#  ['Jul-2012', '506702'],
#  ['Aug-2012', '-1022534'],
#  ['Sep-2012', '475062'],
#  ['Oct-2012', '779976'],
#  ['Nov-2012', '144175'],
#  ['Dec-2012', '542494'],
# ...
